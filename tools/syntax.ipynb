# %% [markdown]
# # Süntaks EstNLTK abil
#
# * allikas: https://github.com/estnltk/estnltk/blob/version_1.6/tutorials/syntax/syntax.ipynb
# * Maltparseri mudelite kaust: /home/nemee/anaconda3/envs/py38/lib/python3.8/site-packages/estnltk/taggers/syntax/udpipe_tagger/resources
# * UD_Estonian: https://github.com/UniversalDependencies/UD_Estonian-EWT/blob/master/et_ewt-ud-train.conllu

# %%
from estnltk.taggers import UDPipeTagger
from estnltk import Text
from estnltk.taggers import ConllMorphTagger
import warnings
warnings.filterwarnings('ignore')
# Out:
# INFO:utils.py:159: NumExpr defaulting to 8 threads.

# %%
# text = Text("Tema tahtis saada rikkaks ja kuulsaks ja elada kodanlikku elu .")
# text = Text("Selle nädala kolmapäeval teatas firma, et nad jõuavad eesmärgini koguni viis kuud enne tähtaega, vahendas Reuters.")
text = Text("Selle nädala kolmapäeval teatas firma, et nad jõuavad eesmärgini koguni viis kuud enne tähtaega, vahendas Reuters.")
text.analyse('all')
# Out:
# Text(text='Selle nädala kolmapäeval teatas firma, et nad jõuavad eesmärgini koguni viis kuud enne tähtaega, vahendas Reuters.')

# %%
conll_morph = ConllMorphTagger() # adding conll_morph layer 
conll_morph.tag(text)
# Out:
# Text(text='Selle nädala kolmapäeval teatas firma, et nad jõuavad eesmärgini koguni viis kuud enne tähtaega, vahendas Reuters.')

# %%
udpipe_tagger = UDPipeTagger() # by default it uses conll_morph as an input layer
udpipe_tagger.tag(text)
text.udpipe_syntax
# Out:
# Layer(name='udpipe_syntax', attributes=('id', 'form', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc'), spans=SL[Span('Selle', [{'id': 1, 'form': 'Selle', 'lemma': 'see', 'upostag': 'P', 'xpostag': 'P', 'feats': OrderedDict([('dem', ''), ('sg', ''), ('gen', '')]), 'head': 2, 'deprel': '@NN>', 'deps': '_', 'misc': '_'}]),
# Span('nädala', [{'id': 2, 'form': 'nädala', 'lemma': 'nädal', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('sg', ''), ('gen', '')]), 'head': 3, 'deprel': '@NN>', 'deps': '_', 'misc': '_'}]),
# Span('kolmapäeval', [{'id': 3, 'form': 'kolmapäeval', 'lemma': 'kolma_päev', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('sg', ''), ('ad', '')]), 'head': 4, 'deprel': '@ADVL', 'deps': '_', 'misc': '_'}]),
# ...

# %%
from estnltk.taggers.syntax.stanza_tagger.stanza_tagger import StanzaSyntaxTagger

# text = Text("Tema tahtis saada rikkaks ja kuulsaks ja elada kodanlikku elu .")
text = Text("Selle nädala kolmapäeval teatas firma, et nad jõuavad eesmärgini koguni viis kuud enne tähtaega, vahendas Reuters.")
text.analyse('all')

stanza_tagger = StanzaSyntaxTagger(input_type='morph_analysis')

stanza_tagger.tag( text )

text.stanza_syntax
# Out:
# Layer(name='stanza_syntax', attributes=('id', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc'), spans=SL[Span('Selle', [{'id': 1, 'lemma': 'see', 'upostag': 'P', 'xpostag': 'P', 'feats': OrderedDict([('sg', 'sg'), ('g', 'g')]), 'head': 2, 'deprel': 'det', 'deps': '_', 'misc': '_'}]),
# Span('nädala', [{'id': 2, 'lemma': 'nädal', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('sg', 'sg'), ('g', 'g')]), 'head': 3, 'deprel': 'nmod', 'deps': '_', 'misc': '_'}]),
# Span('kolmapäeval', [{'id': 3, 'lemma': 'kolmapäev', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('sg', 'sg'), ('ad', 'ad')]), 'head': 4, 'deprel': 'obl', 'deps': '_', 'misc': '_'}]),
# Span('teatas', [{'id': 4, 'lemma': 'teatama', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('s', 's')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_'}]),
# ...

# %%
import stanza
# stanza.download('et', processors='tokenize,pos,lemma,depparse')

# %%
stanza_tagger_sent = StanzaSyntaxTagger(input_type='sentences', 
                                        output_layer='stanza_syntax_sent', 
                                        depparse_path='',)
                                       #resources_path='/home/nemee/stanza_resources')

stanza_tagger_sent.tag( text )

text.stanza_syntax_sent
# Out:
# Layer(name='stanza_syntax_sent', attributes=('id', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc'), spans=SL[Span('Selle', [{'id': 1, 'lemma': 'see', 'upostag': 'DET', 'xpostag': 'P', 'feats': OrderedDict([('Case', 'Gen'), ('Number', 'Sing'), ('PronType', 'Dem')]), 'head': 2, 'deprel': 'det', 'deps': '_', 'misc': '_'}]),
# Span('nädala', [{'id': 2, 'lemma': 'nädal', 'upostag': 'NOUN', 'xpostag': 'S', 'feats': OrderedDict([('Case', 'Gen'), ('Number', 'Sing')]), 'head': 3, 'deprel': 'nmod', 'deps': '_', 'misc': '_'}]),
# Span('kolmapäeval', [{'id': 3, 'lemma': 'kolma_päev', 'upostag': 'NOUN', 'xpostag': 'S', 'feats': OrderedDict([('Case', 'Ade'), ('Number', 'Sing')]), 'head': 4, 'deprel': 'obl', 'deps': '_', 'misc': '_'}]),
# ...
